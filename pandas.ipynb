# %%
import pandas as pd

# %%
a=pd.read_csv("/sample_ipl_data.csv")

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
b=pd.read_csv("/sample_ipl_data.csv",index_col='Team',squeeze=True)
b
# Out:
# <ipython-input-8-9e3c5cc0318b>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   b=pd.read_csv("/sample_ipl_data.csv",index_col='Team',squeeze=True)
#         Unnamed: 0  Year  Points
# Team
# Riders           0  2014     876
# Riders           1  2015     789
# Devils           2  2014     863
# Devils           3  2015     673
# Kings            4  2014     741
# kings            5  2015     812
# Kings            6  2016     756
# Kings            7  2017     788
# Riders           8  2016     694
# Royals           9  2014     701
# Royals          10  2015     804
# Riders          11  2017     690

# %%
b.head()
# Out:
#         Unnamed: 0  Year  Points
# Team
# Riders           0  2014     876
# Riders           1  2015     789
# Devils           2  2014     863
# Devils           3  2015     673
# Kings            4  2014     741

# %%
b.tail()
# Out:
#         Unnamed: 0  Year  Points
# Team
# Kings            7  2017     788
# Riders           8  2016     694
# Royals           9  2014     701
# Royals          10  2015     804
# Riders          11  2017     690

# %%
b.sample(4)
# Out:
#         Unnamed: 0  Year  Points
# Team
# Riders           0  2014     876
# Riders           1  2015     789
# Devils           3  2015     673
# Royals           9  2014     701

# %%
b.value_counts()
# Out:
# Unnamed: 0  Year  Points
# 0           2014  876       1
# 1           2015  789       1
# 2           2014  863       1
# 3           2015  673       1
# 4           2014  741       1
# 5           2015  812       1
# 6           2016  756       1
# 7           2017  788       1
# 8           2016  694       1
# 9           2014  701       1
# 10          2015  804       1
# 11          2017  690       1
# dtype: int64

# %%
b.sort_values(by='Year')
# Out:
#         Unnamed: 0  Year  Points
# Team
# Riders           0  2014     876
# Devils           2  2014     863
# Kings            4  2014     741
# Royals           9  2014     701
# Riders           1  2015     789
# Devils           3  2015     673
# kings            5  2015     812
# Royals          10  2015     804
# Kings            6  2016     756
# Riders           8  2016     694
# Kings            7  2017     788
# Riders          11  2017     690

# %%
b.sort_values(by='Year').head().values[0]
# Out:
# array([   0, 2014,  876])

# %%
b.sort_index().tail(2)
# Out:
#         Unnamed: 0  Year  Points
# Team
# Royals          10  2015     804
# kings            5  2015     812

# %%
b.count()
# Out:
# Unnamed: 0    12
# Year          12
# Points        12
# dtype: int64

# %%
sum1=b.groupby('Year')['Points']
print(sum1.sum())
# Out:
# Year
# 2014    3181
# 2015    3078
# 2016    1450
# 2017    1478
# Name: Points, dtype: int64

# %%
sum1.median()
# Out:
# Year
# 2014    802.0
# 2015    796.5
# 2016    725.0
# 2017    739.0
# Name: Points, dtype: float64

# %%
sum1.mean()
# Out:
# Year
# 2014    795.25
# 2015    769.50
# 2016    725.00
# 2017    739.00
# Name: Points, dtype: float64

# %%
sum1.describe()
# Out:
#       count    mean        std    min    25%    50%     75%    max
# Year
# 2014    4.0  795.25  87.439026  701.0  731.0  802.0  866.25  876.0
# 2015    4.0  769.50  65.035888  673.0  760.0  796.5  806.00  812.0
# 2016    2.0  725.00  43.840620  694.0  709.5  725.0  740.50  756.0
# 2017    2.0  739.00  69.296465  690.0  714.5  739.0  763.50  788.0

# %%
b[::2]
# Out:
#         Unnamed: 0  Year  Points
# Team
# Riders           0  2014     876
# Devils           2  2014     863
# Kings            4  2014     741
# Kings            6  2016     756
# Riders           8  2016     694
# Royals          10  2015     804

# %%
b[4:6]
# Out:
#        Unnamed: 0  Year  Points
# Team
# Kings           4  2014     741
# kings           5  2015     812

# %%
one=read_csv("/one_t.xlsx")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-31-19e6aeb93710> in <cell line: 1>()
# ----> 1 one=pd.read_csv("/one_t.xlsx")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
print(len(b))
print(type(b))
#print(sorted(b))
print(max(b))
# Out:
# 12
# <class 'pandas.core.frame.DataFrame'>
# Year

# %%
list(b)
dict(b)
# Out:
# {'Unnamed: 0': Team
#  Riders     0
#  Riders     1
#  Devils     2
#  Devils     3
#  Kings      4
#  kings      5
#  Kings      6
#  Kings      7
#  Riders     8
#  Royals     9
#  Royals    10
#  Riders    11
#  Name: Unnamed: 0, dtype: int64,
#  'Year': Team
#  Riders    2014
#  Riders    2015
#  Devils    2014
#  Devils    2015
#  Kings     2014
#  kings     2015
#  Kings     2016
#  Kings     2017
#  Riders    2016
#  Royals    2014
#  Royals    2015
#  Riders    2017
#  Name: Year, dtype: int64,
#  'Points': Team
#  Riders    876
#  Riders    789
#  Devils    863
#  Devils    673
#  Kings     741
#  kings     812
#  Kings     756
#  Kings     788
#  Riders    694
#  Royals    701
#  Royals    804
#  Riders    690
#  Name: Points, dtype: int64}
